# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the data
df = pd.read_csv("minerals_price_changes.csv",low_memory=False)
df.drop(df.columns[7:], inplace = True, axis = 1)

# %%
df.head()
# Out:
#      Year Month  Price_alum Price_gold  Price_nickel  Price_silver  Price_uran
# 0  1992.0   Feb     1266.83     353.91        7861.9          4.15        7.90
# 1  1992.0   Mar     1280.47     344.34        7417.7          4.11        7.75
# 2  1992.0   Apr     1317.05     338.62        7420.6          4.05        7.75
# 3  1992.0   May     1306.79     337.24        7326.8          4.07        7.55
# 4  1992.0   Jun     1275.55     340.81        7192.8          4.06        7.75

# %%
df.groupby('Year').agg(sum).head()
# Out:
#         Price_alum  Price_nickel  Price_silver  Price_uran
# Year
# 1992.0    13874.33      76497.45         43.24       94.00
# 1993.0    13668.59      63521.03         51.70      120.93
# 1994.0    17721.39      76077.84         63.42      113.05
# 1995.0    21667.89      98736.47         62.40      139.98
# 1996.0    18067.93      90009.80         62.43      187.25

# %%
df.drop("Price_silver", axis = 1, inplace = True)
df.head()
# Out:
#      Year Month  Price_alum Price_gold  Price_nickel  Price_uran
# 0  1992.0   Feb     1266.83     353.91        7861.9        7.90
# 1  1992.0   Mar     1280.47     344.34        7417.7        7.75
# 2  1992.0   Apr     1317.05     338.62        7420.6        7.75
# 3  1992.0   May     1306.79     337.24        7326.8        7.55
# 4  1992.0   Jun     1275.55     340.81        7192.8        7.75

# %%
df.loc[0:10,['Year','Month','Price_alum', 'Price_gold']]
# Out:
#       Year Month  Price_alum Price_gold
# 0   1992.0   Feb     1266.83     353.91
# 1   1992.0   Mar     1280.47     344.34
# 2   1992.0   Apr     1317.05     338.62
# 3   1992.0   May     1306.79     337.24
# 4   1992.0   Jun     1275.55     340.81
# 5   1992.0   Jul     1313.05     352.72
# 6   1992.0   Aug     1305.05     343.06
# 7   1992.0   Sep     1269.61     345.43
# 8   1992.0   Oct     1173.78     344.38
# 9   1992.0   Nov     1159.05     335.02
# 10  1992.0   Dec     1207.10     334.82

# %%
df.iloc[0:10,:4]
# Out:
#      Year Month  Price_alum Price_gold
# 0  1992.0   Feb     1266.83     353.91
# 1  1992.0   Mar     1280.47     344.34
# 2  1992.0   Apr     1317.05     338.62
# 3  1992.0   May     1306.79     337.24
# 4  1992.0   Jun     1275.55     340.81
# 5  1992.0   Jul     1313.05     352.72
# 6  1992.0   Aug     1305.05     343.06
# 7  1992.0   Sep     1269.61     345.43
# 8  1992.0   Oct     1173.78     344.38
# 9  1992.0   Nov     1159.05     335.02

# %%
df.plot(kind='line',x='Price_gold',y='Year')
# Out:
# <AxesSubplot:xlabel='Price_gold'>

# %%
df = pd.DataFrame({'First Name': ['Aryan', 'Rohan', 'Riya', 'Yash', 'Siddhant', ],
                   'Last Name': ['Singh', 'Agarwal', 'Shah', 'Bhatia', 'Khanna'],
                   'Type': ['Full-time Employee', 'Intern', 'Full-time Employee','Part-time Employee', 'Full-time Employee'],
                   'Department': ['Administration', 'Technical', 'Administration','Technical', 'Management'],
                   'YoE': [2, 3, 5, 7, 6],
                   'Salary': [20000, 5000, 10000, 10000, 20000]})

df
# Out:
#   First Name Last Name                Type      Department  YoE  Salary
# 0      Aryan     Singh  Full-time Employee  Administration    2   20000
# 1      Rohan   Agarwal              Intern       Technical    3    5000
# 2       Riya      Shah  Full-time Employee  Administration    5   10000
# 3       Yash    Bhatia  Part-time Employee       Technical    7   10000
# 4   Siddhant    Khanna  Full-time Employee      Management    6   20000

# %%
output = pd.pivot_table(data=df, 
                        index=['Type'], 
                        columns=['Department'], 
                        values='Salary',
                        aggfunc='mean')
output
# Out:
# Department          Administration  Management  Technical
# Type
# Full-time Employee         15000.0     20000.0        NaN
# Intern                         NaN         NaN     5000.0
# Part-time Employee             NaN         NaN    10000.0
